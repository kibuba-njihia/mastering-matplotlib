# %% [markdown]
# <a href="https://colab.research.google.com/github/kibuba-njihia/mastering-matplotlib/blob/main/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# The plot() function by default draws a line from one point to another given inputs. To plot only the markers, you can use 'o'

# %%
xpoints = np.array([-3, 6])
ypoints = np.array([50, 250])

plt.plot(xpoints, ypoints,'o') # .plot is used to create a line plot
plt.show()

# %% [markdown]
# To plot multiple points, you can pass the array of the points. They should be of the same length

# %%
x_axis=np.array([-10,2,5,7])
y_axis=np.array([2,0,0,6])

plt.plot(x_axis,y_axis)
plt.show()

# %% [markdown]
# If we do not specify the points on the x-axis, they will get the default values 0, 1, 2, 3 etc., depending on the length of the y-points.

# %%
x_axis=np.array([2,0,0,6])

plt.plot(x_axis)
plt.show()

# %% [markdown]
# Markers: To mark specific points on the plot

# %% [markdown]
# You can add many more params for colors, line type, etc

# %%
x_axis=np.array([2,0,3,6])

plt.plot(x_axis,'o--',marker='h',ms = 10,mec = 'r',c = '#4CAF10',mfc = '#4CAF50')
plt.show()
# Out:
# <ipython-input-57-91b36450bfd4>:3: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o--" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot(x_axis,'o--',marker='h',ms = 10,mec = 'r',c = '#4CAF10',mfc = '#4CAF50')

# %% [markdown]
# ### Plotting multiple lines.

# %% [markdown]
# Done by adding more plt.plot() functions:

# %%
a=np.array([1,6])
b=np.array([-20,60])

plt.plot(a)
plt.plot(b)
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py'>

# %% [markdown]
# ### **Labels and Title**

# %% [markdown]
# Use xlabel() and ylabel() functions for labels and title() for the title.

# %%
array_one=np.array([1,6])
array_two=np.array([-20,60])

plt.plot(array_one)
plt.plot(array_two)

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.xlabel("x-axis",fontdict=font1,size=12)
plt.ylabel("y-axis",fontdict=font1,size=12)
plt.title("Line Plot",fontdict=font2,size=20,loc='Center')
plt.grid(axis='y',color = 'green', linestyle = '--', linewidth = 0.5) # Adding gridlines
plt.show()

# %% [markdown]
# ### **Display Multiple Plots**

# %% [markdown]
# Use subplot() function which takes in 3 args. 1st & 2nd are the rows and columns, 3rd is the index of the plot.
#
# plt.subplot(1, 2, 1) - The figure has 1 row, 2 columns, and this plot is the first plot.
#
# plt.subplot(1, 2, 2) - The figure has 1 row, 2 columns, and this plot is the second plot.

# %%
#First plot
a=np.array([10,6])
b=np.array([-20,60])

plt.subplot(1,2,1)
plt.plot(a,b)
plt.title("Loss")

#Second plot
c=np.array([3,8])
d=np.array([1,4])

plt.subplot(1,2,2)
plt.plot(c,d)
plt.title("Income")

plt.suptitle("Trend")
plt.show()

# %% [markdown]
# ### **Scatter plots**

# %% [markdown]
# Use .scatter() ftn. It needs two arrays of the same length, one for the values of the x-axis, and one for values on the y-axis:

# %%
#day one, the age and speed of 13 cars:
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color = 'hotpink')

#day two, the age and speed of 15 cars:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([10,10,8,10,9,9,9,5,4,10,7,11,1,8,8])
plt.scatter(x, y)
plt.show()

# %% [markdown]
# ####Adding colorbar

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='copper')

plt.colorbar()

plt.show()

# %% [markdown]
# ####Changing size

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes,alpha=0.5)

plt.show()

# %%
x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')

plt.colorbar()

plt.show()

# %% [markdown]
# ### **Plotting bar charts**

# %% [markdown]
# Use the bar() ftn.
#
# If you want the bars to be displayed horizontally instead of vertically, use the barh().
#
# The default width value is 0.8

# %%
a=np.array([1,2,3,4])
b=np.array([5,6,7,8])

plt.bar(a,b,color='red',width = 0.1)
plt.show()

# %% [markdown]
# ### **Histograms**

# %% [markdown]
# Use the hist() function.

# %%
x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()

# %% [markdown]
# ### **Pie Charts**

# %% [markdown]
#  Use the pie() function.
#
#  By default the plotting of the first wedge starts from the x-axis and moves counterclockwise. You can change the start angle by specifying a startangle parameter.

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.1, 0, 0, 0]

plt.pie(y, labels = mylabels, startangle = 90, explode = myexplode, shadow=True)
plt.legend(title = "Fruits:")
plt.show()

# %% [markdown]
# ##**Practising**

# %% [markdown]
# Let's try create this image:

# %% [markdown]
# ![HOPS-Distribution-by-Position.png](data:image/png;base64,...)

# %% [markdown]
# 1.   Get to know the plot type: This is a stack plot.
# 2.   Get the syntax plot a basic Stack Plot

# %% [markdown]
# ##Using a simple array function as input in a plot.

# %%
def get_exponential(x,y):
  x_array=[]
  y_array=[]
  while x < y:
    x_array.append(x)
    y_array.append(y)

    x=x+1
    y=y-1
  return x_array,y_array

# %%
get_exponential(1,10)
# Out:
# ([1, 2, 3, 4, 5], [10, 9, 8, 7, 6])

# %%
a=np.array([1,2,3,4])
b=np.array([4,5,6,7])
c,d=get_exponential(1,10)

plt.stackplot(c,d)
plt.show()

# %%
x=np.arange(0,10,2)
x
# Out:
# array([0, 2, 4, 6, 8])

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

# make data
x = np.arange(0, 10, 2)
ay = [1, 1.25, 2, 2.75, 3]
by = [1, 1, 1, 1, 1]
cy = [2, 1, 2, 1, 2]
y = np.vstack([ay, by, cy])

# plot
fig, ax = plt.subplots()

ax.stackplot(x, y)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()
